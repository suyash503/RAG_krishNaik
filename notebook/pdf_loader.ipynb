# %% [markdown]
# ###Data Ingestioon to vector DB -RAG PIPELINE

# %%
import os
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from pathlib import Path

# %%
##read all the pdfs
def process_all_pdfs(pdf_directory):
    """"Process all the pdfs in the directory"""
    all_documents = []
    pdf_dir = Path(pdf_directory)

    #find all pdfs recursively
    pdf_files = list(pdf_dir.glob("**/*.pdf"))

    print(f"found {len(pdf_files)} PDF files to process")

    for pdf_file in pdf_files:
        print(f"\nProcessing: {pdf_file.name}")
        try:
            loader = PyMuPDFLoader(str(pdf_file))
            documents = loader.load()

            for doc in documents:
                page_num = doc.metadata.get("page", 0) + 1
                doc.metadata['source_file'] = pdf_file.name
                doc.metadata['file_type'] = 'pdf' 
                doc.metadata['page_label'] = f"Page {page_num}"

            all_documents.extend(documents)
            print(f"loaded {len(documents)} pages")

        except Exception as e:
            print(f" Error, failed to load: {e}")

    print(f"total documents loaded: {len(all_documents)}")
    return all_documents
#process all the pdfs
all_pdf_documents = process_all_pdfs("../data")
# Out:
# found 3 PDF files to process
#
# Processing: bheeni resume.pdf
# loaded 1 pages
#
# Processing: DAA U-4.pdf
# loaded 132 pages
#
# Processing: suyash_res (9) (1).pdf
# loaded 1 pages
# total documents loaded: 134

# %%
all_pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Bheeni Agarwal\n\x83 +91-7068082628\n—\n# bheeniagarwal07@gmail.com\n—\nï LinkedIn\n—\n§ GitHub\n—\nLeetCode\n—\nPortfolio\nProfessional Summary\nB.Tech CSE Data Science student with strong foundation in Machine Learning, Statistical Analysis, and Data-driven Problem\nSolving. Proficient in Python, Java, and ML frameworks with hands-on experience building predictive models and data\nvisualization projects. Completed 3+ certified data science programs from IIT Kharagpur and deployed 5+ end-to-end ML\napplications. Seeking opportunities to leverage analytical skills and programming expertise in AI ML Data Science roles.\nEducation\nAjay Kumar Garg Engineering College (AKGEC)\nSept 2024 – Sept 2027\nBachelor of Technology in Computer Science and Engineering (Data Science)\nGhaziabad, UP\nGalgotias University\nAug 2022 – May 2024\nPolytechnic Diploma in Computer Science and Engineering\nGreater Noida, UP\nH.M Memorial School\nApr 2020 – Jun 2022\nSenior Secondary Education (PCM)\nJhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS\nData Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras\nMachine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation\nData Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI\nDatabase Technologies: MySQL, PostgreSQL, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman\nCore Competencies: Statistical Analysis, Data Visualization, Exploratory Data Analysis, Predictive Modeling, A/B\nTesting, ETL\nProjects\nTitanic Survival Prediction Model — Live — Python, Scikit-learn, Pandas, Logistic Regression\nGitHub\n• Developed machine learning classification model to predict passenger survival on Titanic dataset with 82% accuracy\n• Performed comprehensive EDA, handled missing values, engineered features including family size and fare binning\n• Implemented logistic regression with hyperparameter tuning and evaluated model using precision, recall, and F1-score\n• Deployed interactive prediction interface and visualized feature importance using confusion matrix and ROC curves\nStudent Performance Analysis System — Live — Python, Pandas, Seaborn, Statistical Modeling\nGitHub\n• Conducted exploratory data analysis on 1000+ student records to identify factors affecting academic performance\n• Applied statistical techniques including correlation analysis, hypothesis testing, and distribution analysis\n• Created 15+ data visualizations using Matplotlib and Seaborn to communicate insights to stakeholders\n• Discovered significant correlations between parental education, study time, and exam scores with 95% confidence level\nReal-Time Weather Forecast Application — Live — JavaScript, HTML/CSS, OpenWeather API, REST\nGitHub\n• Built responsive web application fetching real-time weather data for 200+ global cities using OpenWeather API\n• Implemented asynchronous JavaScript with Promises and async/await for efficient API data retrieval\n• Designed modern UI with CSS animations and dynamic content rendering based on weather conditions\n• Integrated geolocation services to provide personalized weather information based on user location\nExperience\nTraining and Placement Cell, AKGEC\nMay 2025 – Present\nStudent Coordinator\nGhaziabad, UP\n• Coordinate campus recruitment drives managing data for 500+ students across multiple en ...
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 0, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 1, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 2'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 2, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 3'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 3, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 4'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 4, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 5'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 5, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 6'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 6, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 7'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 7, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 8'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 8, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 9'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 9, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 10'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 10, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 11'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 11, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 12'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 12, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 13'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 13, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 14'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 14, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 15'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 15, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 16'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 16, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 17'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 17, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 18'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 18, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 19'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 19, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 20'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 20, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 21'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 21, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 22'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 22, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 23'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 23, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 24'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 24, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 25'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 25, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 26'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 26, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 27'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 27, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 28'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 28, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 29'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 29, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 30'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 30, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 31'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 31, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 32'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 32, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 33'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 33, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 34'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 34, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 35'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 35, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 36'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 36, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 37'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 37, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 38'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 38, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 39'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 39, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 40'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 40, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 41'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 41, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 42'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 42, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 43'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 43, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 44'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 44, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 45'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 45, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 46'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 46, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 47'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 47, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 48'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 48, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 49'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 49, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 50'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 50, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 51'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 51, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 52'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 52, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 53'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 53, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 54'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 54, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 55'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 55, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 56'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 56, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 57'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 57, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 58'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 58, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 59'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 59, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 60'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 60, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 61'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 61, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 62'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 62, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 63'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 63, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 64'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 64, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 65'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 65, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 66'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 66, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 67'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 67, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 68'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 68, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 69'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 69, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 70'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 70, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 71'}, page_content=''),
# ...
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 112, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 113'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 113, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 114'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 114, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 115'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 115, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 116'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 116, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 117'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 117, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 118'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 118, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 119'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 119, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 120'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 120, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 121'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 121, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 122'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 122, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 123'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 123, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 124'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 124, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 125'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 125, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 126'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 126, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 127'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 127, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 128'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 128, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 129'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 129, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 130'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 130, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 131'}, page_content=''),
#  Document(metadata={'producer': '4-Heights™ PDF Library 3.4.0.6904 (http://www.pdf-tools.com)', 'creator': 'PDFsharp 1.32.3057-g (www.pdfsharp.net)', 'creationdate': '2024-12-13T11:51:08+05:30', 'source': '..\\data\\pdf\\DAA U-4.pdf', 'file_path': '..\\data\\pdf\\DAA U-4.pdf', 'total_pages': 132, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-12-19T06:11:27+00:00', 'trapped': '', 'modDate': 'D:20241219061127Z', 'creationDate': "D:20241213115108+05'30'", 'page': 131, 'source_file': 'DAA U-4.pdf', 'file_type': 'pdf', 'page_label': 'Page 132'}, page_content=''),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Suyash Singh\n\x83 8318176090\n# suyashsingh2711@gmail.com\nï linkedin.com/in/suyash-singh\n§ github.com/suyash503\nPROFESSIONAL SUMMARY\n3rd-year B.Tech Computer Science student at AKGEC with a high-impact focus on bridging the gap between Full-Stack\nEngineering and Machine Learning. Expertly proficient in Python and JavaScript (React, Next.js), with a proven\ntrack record of architecting end-to-end predictive systems—from training XGBoost models to deploying high-concurrency\nAPIs with FastAPI. Recognized as a Training and Placement Cell Coordinator, managing data-driven recruitment\nworkflows while maintaining a portfolio of deployed applications featuring sub-100ms latency. Passionate about building\nscalable, data-intelligent products that prioritize performance and user-centric design.\nEDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP\nBachelor of Technology in Computer Science and Engineering\nSept 2023 – Present\nMontfort Inter College\nLucknow, UP\nSenior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman\nML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS\nEduHealth: AI-Driven Student Wellness Predictive System | Python, Scikit-learn, FastAPI, React.js\n• Engineered a predictive pipeline using Random Forest and XGBoost to forecast student GPA with 94% accuracy,\nanalyzing 20+ behavioral metrics.\n• Applied SHAP (Explainable AI) to interpret model decisions, identifying physical activity as a top-3 predictor of\nacademic success.\n• Architected a high-concurrency interface with FastAPI to serve model inferences with sub-100ms response times.\n• Optimized model generalization using K-Fold Cross-Validation, ensuring a consistent R2 score of 0.95 across diverse\nstudent profiles.\nWORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.\n• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.\nCERTIFICATIONS\n• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)\nVerify\n• The Web Developer Bootcamp 2025 – Udemy\nVerify\n• Google Digital Marketing Certificate – Google\nVerify\n• Marketing Internship – Universal Tribes\nCompleted June 2025')]

# %%
###chunking

def split_documents(documents, chunk_size = 300, chunk_overlap = 200):
    """split documents into smaller chunks for better rag performance"""

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap,
        length_function = len,
        separators=["\n\n", "\n", " ", ""]
    )

    split_docs = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(split_docs)} chunks")
##show exaple of a chunk
    if split_docs:
        print(f"\nexample chunk:")
        print(f"Content: {split_docs[0].page_content[:200]}...")
        print(f"Metadta: {split_docs[0].metadata}")

    return split_docs

# %%
chunks = split_documents(all_pdf_documents)
chunks
# Out:
# Split 134 documents into 59 chunks
#
# example chunk:
# Content: Bheeni Agarwal
#  +91-7068082628
# —
# # bheeniagarwal07@gmail.com
# —
# ï LinkedIn
# —
# § GitHub
# —
# LeetCode
# —
# Portfolio
# Professional Summary
# B.Tech CSE Data Science student with strong foundation in Machine Lear...
# Metadta: {'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Bheeni Agarwal\n\x83 +91-7068082628\n—\n# bheeniagarwal07@gmail.com\n—\nï LinkedIn\n—\n§ GitHub\n—\nLeetCode\n—\nPortfolio\nProfessional Summary\nB.Tech CSE Data Science student with strong foundation in Machine Learning, Statistical Analysis, and Data-driven Problem'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='—\n§ GitHub\n—\nLeetCode\n—\nPortfolio\nProfessional Summary\nB.Tech CSE Data Science student with strong foundation in Machine Learning, Statistical Analysis, and Data-driven Problem\nSolving. Proficient in Python, Java, and ML frameworks with hands-on experience building predictive models and data'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Solving. Proficient in Python, Java, and ML frameworks with hands-on experience building predictive models and data\nvisualization projects. Completed 3+ certified data science programs from IIT Kharagpur and deployed 5+ end-to-end ML'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='visualization projects. Completed 3+ certified data science programs from IIT Kharagpur and deployed 5+ end-to-end ML\napplications. Seeking opportunities to leverage analytical skills and programming expertise in AI ML Data Science roles.\nEducation\nAjay Kumar Garg Engineering College (AKGEC)'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='applications. Seeking opportunities to leverage analytical skills and programming expertise in AI ML Data Science roles.\nEducation\nAjay Kumar Garg Engineering College (AKGEC)\nSept 2024 – Sept 2027\nBachelor of Technology in Computer Science and Engineering (Data Science)\nGhaziabad, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Education\nAjay Kumar Garg Engineering College (AKGEC)\nSept 2024 – Sept 2027\nBachelor of Technology in Computer Science and Engineering (Data Science)\nGhaziabad, UP\nGalgotias University\nAug 2022 – May 2024\nPolytechnic Diploma in Computer Science and Engineering\nGreater Noida, UP\nH.M Memorial School'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Ghaziabad, UP\nGalgotias University\nAug 2022 – May 2024\nPolytechnic Diploma in Computer Science and Engineering\nGreater Noida, UP\nH.M Memorial School\nApr 2020 – Jun 2022\nSenior Secondary Education (PCM)\nJhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Greater Noida, UP\nH.M Memorial School\nApr 2020 – Jun 2022\nSenior Secondary Education (PCM)\nJhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS\nData Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Jhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS\nData Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras\nMachine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Data Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras\nMachine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation\nData Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Machine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation\nData Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI\nDatabase Technologies: MySQL, PostgreSQL, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Data Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI\nDatabase Technologies: MySQL, PostgreSQL, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman\nCore Competencies: Statistical Analysis, Data Visualization, Exploratory Data Analysis, Predictive Modeling, A/B'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Developer Tools: Git, GitHub, VS Code, REST APIs, Postman\nCore Competencies: Statistical Analysis, Data Visualization, Exploratory Data Analysis, Predictive Modeling, A/B\nTesting, ETL\nProjects\nTitanic Survival Prediction Model — Live — Python, Scikit-learn, Pandas, Logistic Regression\nGitHub'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Testing, ETL\nProjects\nTitanic Survival Prediction Model — Live — Python, Scikit-learn, Pandas, Logistic Regression\nGitHub\n• Developed machine learning classification model to predict passenger survival on Titanic dataset with 82% accuracy'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='GitHub\n• Developed machine learning classification model to predict passenger survival on Titanic dataset with 82% accuracy\n• Performed comprehensive EDA, handled missing values, engineered features including family size and fare binning'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Performed comprehensive EDA, handled missing values, engineered features including family size and fare binning\n• Implemented logistic regression with hyperparameter tuning and evaluated model using precision, recall, and F1-score'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Implemented logistic regression with hyperparameter tuning and evaluated model using precision, recall, and F1-score\n• Deployed interactive prediction interface and visualized feature importance using confusion matrix and ROC curves'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Deployed interactive prediction interface and visualized feature importance using confusion matrix and ROC curves\nStudent Performance Analysis System — Live — Python, Pandas, Seaborn, Statistical Modeling\nGitHub'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Student Performance Analysis System — Live — Python, Pandas, Seaborn, Statistical Modeling\nGitHub\n• Conducted exploratory data analysis on 1000+ student records to identify factors affecting academic performance'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='GitHub\n• Conducted exploratory data analysis on 1000+ student records to identify factors affecting academic performance\n• Applied statistical techniques including correlation analysis, hypothesis testing, and distribution analysis'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Applied statistical techniques including correlation analysis, hypothesis testing, and distribution analysis\n• Created 15+ data visualizations using Matplotlib and Seaborn to communicate insights to stakeholders'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Created 15+ data visualizations using Matplotlib and Seaborn to communicate insights to stakeholders\n• Discovered significant correlations between parental education, study time, and exam scores with 95% confidence level'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Discovered significant correlations between parental education, study time, and exam scores with 95% confidence level\nReal-Time Weather Forecast Application — Live — JavaScript, HTML/CSS, OpenWeather API, REST\nGitHub'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Real-Time Weather Forecast Application — Live — JavaScript, HTML/CSS, OpenWeather API, REST\nGitHub\n• Built responsive web application fetching real-time weather data for 200+ global cities using OpenWeather API'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='GitHub\n• Built responsive web application fetching real-time weather data for 200+ global cities using OpenWeather API\n• Implemented asynchronous JavaScript with Promises and async/await for efficient API data retrieval'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Implemented asynchronous JavaScript with Promises and async/await for efficient API data retrieval\n• Designed modern UI with CSS animations and dynamic content rendering based on weather conditions'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Designed modern UI with CSS animations and dynamic content rendering based on weather conditions\n• Integrated geolocation services to provide personalized weather information based on user location\nExperience\nTraining and Placement Cell, AKGEC\nMay 2025 – Present\nStudent Coordinator\nGhaziabad, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Experience\nTraining and Placement Cell, AKGEC\nMay 2025 – Present\nStudent Coordinator\nGhaziabad, UP\n• Coordinate campus recruitment drives managing data for 500+ students across multiple engineering streams'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='May 2025 – Present\nStudent Coordinator\nGhaziabad, UP\n• Coordinate campus recruitment drives managing data for 500+ students across multiple engineering streams\n• Maintain student placement database using Excel and SQL for tracking applications and interview schedules'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Maintain student placement database using Excel and SQL for tracking applications and interview schedules\n• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer\nGhaziabad, UP\n• Design promotional materials including posters, banners, and social media content for 20+ college events'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Team Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer\nGhaziabad, UP\n• Design promotional materials including posters, banners, and social media content for 20+ college events\n• Collaborate with team members using Figma and Canva to create cohesive visual branding campaigns'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Collaborate with team members using Figma and Canva to create cohesive visual branding campaigns\n• Apply data-driven design principles by analyzing engagement metrics to optimize visual content performance\nCertifications and Achievements'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Apply data-driven design principles by analyzing engagement metrics to optimize visual content performance\nCertifications and Achievements\nCertifications: AI and Data Science Program (IIT Kharagpur) | Machine Learning with Python (Coursera-IBM) | Java'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Certifications and Achievements\nCertifications: AI and Data Science Program (IIT Kharagpur) | Machine Learning with Python (Coursera-IBM) | Java\nDSA Bootcamp (Coding Ninjas) | SQL for Data Science (Coursera-UC Davis) | Python for DS and ML (Udemy)'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='DSA Bootcamp (Coding Ninjas) | SQL for Data Science (Coursera-UC Davis) | Python for DS and ML (Udemy)\nAchievements: GSSoC’25 Contributor - Selected for open-source ML projects | Top Performer - AI Camp by IIT KGP\n(Top 10% of 500+) | Best Project Award - Data Science Track by AKGEC faculty'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Suyash Singh\n\x83 8318176090\n# suyashsingh2711@gmail.com\nï linkedin.com/in/suyash-singh\n§ github.com/suyash503\nPROFESSIONAL SUMMARY\n3rd-year B.Tech Computer Science student at AKGEC with a high-impact focus on bridging the gap between Full-Stack'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='ï linkedin.com/in/suyash-singh\n§ github.com/suyash503\nPROFESSIONAL SUMMARY\n3rd-year B.Tech Computer Science student at AKGEC with a high-impact focus on bridging the gap between Full-Stack\nEngineering and Machine Learning. Expertly proficient in Python and JavaScript (React, Next.js), with a proven'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Engineering and Machine Learning. Expertly proficient in Python and JavaScript (React, Next.js), with a proven\ntrack record of architecting end-to-end predictive systems—from training XGBoost models to deploying high-concurrency'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='track record of architecting end-to-end predictive systems—from training XGBoost models to deploying high-concurrency\nAPIs with FastAPI. Recognized as a Training and Placement Cell Coordinator, managing data-driven recruitment'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='APIs with FastAPI. Recognized as a Training and Placement Cell Coordinator, managing data-driven recruitment\nworkflows while maintaining a portfolio of deployed applications featuring sub-100ms latency. Passionate about building'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='workflows while maintaining a portfolio of deployed applications featuring sub-100ms latency. Passionate about building\nscalable, data-intelligent products that prioritize performance and user-centric design.\nEDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='scalable, data-intelligent products that prioritize performance and user-centric design.\nEDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP\nBachelor of Technology in Computer Science and Engineering\nSept 2023 – Present\nMontfort Inter College\nLucknow, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='EDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP\nBachelor of Technology in Computer Science and Engineering\nSept 2023 – Present\nMontfort Inter College\nLucknow, UP\nSenior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Sept 2023 – Present\nMontfort Inter College\nLucknow, UP\nSenior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Senior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Programming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman\nML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Developer Tools: Git, GitHub, VS Code, REST APIs, Postman\nML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS\nEduHealth: AI-Driven Student Wellness Predictive System | Python, Scikit-learn, FastAPI, React.js'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='ML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS\nEduHealth: AI-Driven Student Wellness Predictive System | Python, Scikit-learn, FastAPI, React.js\n• Engineered a predictive pipeline using Random Forest and XGBoost to forecast student GPA with 94% accuracy,'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Engineered a predictive pipeline using Random Forest and XGBoost to forecast student GPA with 94% accuracy,\nanalyzing 20+ behavioral metrics.\n• Applied SHAP (Explainable AI) to interpret model decisions, identifying physical activity as a top-3 predictor of\nacademic success.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='analyzing 20+ behavioral metrics.\n• Applied SHAP (Explainable AI) to interpret model decisions, identifying physical activity as a top-3 predictor of\nacademic success.\n• Architected a high-concurrency interface with FastAPI to serve model inferences with sub-100ms response times.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='academic success.\n• Architected a high-concurrency interface with FastAPI to serve model inferences with sub-100ms response times.\n• Optimized model generalization using K-Fold Cross-Validation, ensuring a consistent R2 score of 0.95 across diverse\nstudent profiles.\nWORK EXPERIENCE'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Optimized model generalization using K-Fold Cross-Validation, ensuring a consistent R2 score of 0.95 across diverse\nstudent profiles.\nWORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='student profiles.\nWORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='WORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.\n• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Nov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.\n• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.\nCERTIFICATIONS\n• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.\nCERTIFICATIONS\n• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)\nVerify\n• The Web Developer Bootcamp 2025 – Udemy\nVerify\n• Google Digital Marketing Certificate – Google'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)\nVerify\n• The Web Developer Bootcamp 2025 – Udemy\nVerify\n• Google Digital Marketing Certificate – Google\nVerify\n• Marketing Internship – Universal Tribes\nCompleted June 2025')]

# %% [markdown]
# ### embedding and vector store db

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings
import uuid
from typing import List, Dict, Any, Tuple
from sklearn.metrics.pairwise import cosine_similarity

# %%
class EmbeddingManager:
    """Handles document embedding generation using SentenceTransformers"""

    def __init__(self, model_name: str = "all-MiniLM-L6-v2"):
        """
        
        Initialize the embedding manager

        Args:
            model_name: it is a beginner friendly model available on hugging face platform, which is basically the github for AI devs

        """

        self.model_name = model_name
        self.model = None
        self._load_model()

    def _load_model(self):
        """Load the sentence transformer model"""

        try:
            print(f"loading embedding model: {self.model_name}")
            self.model = SentenceTransformer(self.model_name)
            print(f"Model loaded successfully. embedding dimension: {self.model.get_sentence_embedding_dimension()}")
        except Exception as e:
            print(f"error loading model {self.model_name}: {e}")
            raise

    def generate_embeddings(self, texts: List[str]) -> np.ndarray:

        """
        Generate embeddingsfor a list of texts

        Args:
            texts: List of text stringsto embed

        Returns:
        numpy array of embeddings with shape (len(ttexts), embedding_dim)
        """

        if not self.model:
            raise ValueError("model not loaded")
        
        print(f"generating embeddings for {len(texts)} texts...")
        embeddings = self.model.encode(texts, show_progress_bar=True)
        print(f"Generated embeddings with shape: {embeddings.shape}")
        return embeddings
    
embedding_manager=EmbeddingManager()
embedding_manager
# Out:
# loading embedding model: all-MiniLM-L6-v2
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 329.08it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Model loaded successfully. embedding dimension: 384

# %%
class VectorStore:
    """Manages document embeddings in a ChromaDB vector store"""
    
    def __init__(self, collection_name: str = "pdf_documents", persist_directory: str = "../data/vector_store"):
        """
        Initialize the vector store
        
        Args:
            collection_name: Name of the ChromaDB collection
            persist_directory: Directory to persist the vector store
        """
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.client = None
        self.collection = None
        self._initialize_store()

    def _initialize_store(self):
        """Initialize ChromaDB client and collection"""
        try:
            # Create persistent ChromaDB client
            os.makedirs(self.persist_directory, exist_ok=True)
            self.client = chromadb.PersistentClient(path=self.persist_directory)
            
            # Get or create collection
            self.collection = self.client.get_or_create_collection(
                name=self.collection_name,
                metadata={"description": "PDF document embeddings for RAG"}
            )
            print(f"Vector store initialized. Collection: {self.collection_name}")
            print(f"Existing documents in collection: {self.collection.count()}")
            
        except Exception as e:
            print(f"Error initializing vector store: {e}")
            raise

    def add_documents(self, documents: List[Any], embeddings: np.ndarray):
        """
        Add documents and their embeddings to the vector store
        
        Args:
            documents: List of LangChain documents
            embeddings: Corresponding embeddings for the documents
        """
        if len(documents) != len(embeddings):
            raise ValueError("Number of documents must match number of embeddings")
        
        print(f"Adding {len(documents)} documents to vector store...")
        
        # Prepare data for ChromaDB
        ids = []
        metadatas = []
        documents_text = []
        embeddings_list = []
        
        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            # Generate unique ID
            doc_id = f"doc_{uuid.uuid4().hex[:8]}_{i}"
            ids.append(doc_id)
            
            # Prepare metadata
            metadata = dict(doc.metadata)
            metadata['doc_index'] = i
            metadata['content_length'] = len(doc.page_content)
            metadatas.append(metadata)
            
            # Document content
            documents_text.append(doc.page_content)
            
            # Embedding
            embeddings_list.append(embedding.tolist())
        
        # Add to collection
        try:
            self.collection.add(
                ids=ids,
                embeddings=embeddings_list,
                metadatas=metadatas,
                documents=documents_text
            )
            print(f"Successfully added {len(documents)} documents to vector store")
            print(f"Total documents in collection: {self.collection.count()}")
            
        except Exception as e:
            print(f"Error adding documents to vector store: {e}")
            raise

vectorstore=VectorStore()
vectorstore
# Out:
# Vector store initialized. Collection: pdf_documents
# Existing documents in collection: 236

# %%
chunks
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Bheeni Agarwal\n\x83 +91-7068082628\n—\n# bheeniagarwal07@gmail.com\n—\nï LinkedIn\n—\n§ GitHub\n—\nLeetCode\n—\nPortfolio\nProfessional Summary\nB.Tech CSE Data Science student with strong foundation in Machine Learning, Statistical Analysis, and Data-driven Problem'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='—\n§ GitHub\n—\nLeetCode\n—\nPortfolio\nProfessional Summary\nB.Tech CSE Data Science student with strong foundation in Machine Learning, Statistical Analysis, and Data-driven Problem\nSolving. Proficient in Python, Java, and ML frameworks with hands-on experience building predictive models and data'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Solving. Proficient in Python, Java, and ML frameworks with hands-on experience building predictive models and data\nvisualization projects. Completed 3+ certified data science programs from IIT Kharagpur and deployed 5+ end-to-end ML'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='visualization projects. Completed 3+ certified data science programs from IIT Kharagpur and deployed 5+ end-to-end ML\napplications. Seeking opportunities to leverage analytical skills and programming expertise in AI ML Data Science roles.\nEducation\nAjay Kumar Garg Engineering College (AKGEC)'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='applications. Seeking opportunities to leverage analytical skills and programming expertise in AI ML Data Science roles.\nEducation\nAjay Kumar Garg Engineering College (AKGEC)\nSept 2024 – Sept 2027\nBachelor of Technology in Computer Science and Engineering (Data Science)\nGhaziabad, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Education\nAjay Kumar Garg Engineering College (AKGEC)\nSept 2024 – Sept 2027\nBachelor of Technology in Computer Science and Engineering (Data Science)\nGhaziabad, UP\nGalgotias University\nAug 2022 – May 2024\nPolytechnic Diploma in Computer Science and Engineering\nGreater Noida, UP\nH.M Memorial School'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Ghaziabad, UP\nGalgotias University\nAug 2022 – May 2024\nPolytechnic Diploma in Computer Science and Engineering\nGreater Noida, UP\nH.M Memorial School\nApr 2020 – Jun 2022\nSenior Secondary Education (PCM)\nJhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Greater Noida, UP\nH.M Memorial School\nApr 2020 – Jun 2022\nSenior Secondary Education (PCM)\nJhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS\nData Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Jhansi, UP\nTechnical Skills\nProgramming Languages: Python, Java, SQL, JavaScript, HTML, CSS\nData Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras\nMachine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Data Science Libraries: Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn, TensorFlow, Keras\nMachine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation\nData Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Machine Learning: Supervised Learning, Unsupervised Learning, Regression, Classification, Model Evaluation\nData Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI\nDatabase Technologies: MySQL, PostgreSQL, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Data Analysis Tools: Jupyter Notebook, Google Colab, Excel, Tableau, Power BI\nDatabase Technologies: MySQL, PostgreSQL, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman\nCore Competencies: Statistical Analysis, Data Visualization, Exploratory Data Analysis, Predictive Modeling, A/B'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Developer Tools: Git, GitHub, VS Code, REST APIs, Postman\nCore Competencies: Statistical Analysis, Data Visualization, Exploratory Data Analysis, Predictive Modeling, A/B\nTesting, ETL\nProjects\nTitanic Survival Prediction Model — Live — Python, Scikit-learn, Pandas, Logistic Regression\nGitHub'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Testing, ETL\nProjects\nTitanic Survival Prediction Model — Live — Python, Scikit-learn, Pandas, Logistic Regression\nGitHub\n• Developed machine learning classification model to predict passenger survival on Titanic dataset with 82% accuracy'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='GitHub\n• Developed machine learning classification model to predict passenger survival on Titanic dataset with 82% accuracy\n• Performed comprehensive EDA, handled missing values, engineered features including family size and fare binning'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Performed comprehensive EDA, handled missing values, engineered features including family size and fare binning\n• Implemented logistic regression with hyperparameter tuning and evaluated model using precision, recall, and F1-score'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Implemented logistic regression with hyperparameter tuning and evaluated model using precision, recall, and F1-score\n• Deployed interactive prediction interface and visualized feature importance using confusion matrix and ROC curves'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Deployed interactive prediction interface and visualized feature importance using confusion matrix and ROC curves\nStudent Performance Analysis System — Live — Python, Pandas, Seaborn, Statistical Modeling\nGitHub'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Student Performance Analysis System — Live — Python, Pandas, Seaborn, Statistical Modeling\nGitHub\n• Conducted exploratory data analysis on 1000+ student records to identify factors affecting academic performance'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='GitHub\n• Conducted exploratory data analysis on 1000+ student records to identify factors affecting academic performance\n• Applied statistical techniques including correlation analysis, hypothesis testing, and distribution analysis'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Applied statistical techniques including correlation analysis, hypothesis testing, and distribution analysis\n• Created 15+ data visualizations using Matplotlib and Seaborn to communicate insights to stakeholders'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Created 15+ data visualizations using Matplotlib and Seaborn to communicate insights to stakeholders\n• Discovered significant correlations between parental education, study time, and exam scores with 95% confidence level'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Discovered significant correlations between parental education, study time, and exam scores with 95% confidence level\nReal-Time Weather Forecast Application — Live — JavaScript, HTML/CSS, OpenWeather API, REST\nGitHub'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Real-Time Weather Forecast Application — Live — JavaScript, HTML/CSS, OpenWeather API, REST\nGitHub\n• Built responsive web application fetching real-time weather data for 200+ global cities using OpenWeather API'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='GitHub\n• Built responsive web application fetching real-time weather data for 200+ global cities using OpenWeather API\n• Implemented asynchronous JavaScript with Promises and async/await for efficient API data retrieval'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Implemented asynchronous JavaScript with Promises and async/await for efficient API data retrieval\n• Designed modern UI with CSS animations and dynamic content rendering based on weather conditions'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Designed modern UI with CSS animations and dynamic content rendering based on weather conditions\n• Integrated geolocation services to provide personalized weather information based on user location\nExperience\nTraining and Placement Cell, AKGEC\nMay 2025 – Present\nStudent Coordinator\nGhaziabad, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Experience\nTraining and Placement Cell, AKGEC\nMay 2025 – Present\nStudent Coordinator\nGhaziabad, UP\n• Coordinate campus recruitment drives managing data for 500+ students across multiple engineering streams'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='May 2025 – Present\nStudent Coordinator\nGhaziabad, UP\n• Coordinate campus recruitment drives managing data for 500+ students across multiple engineering streams\n• Maintain student placement database using Excel and SQL for tracking applications and interview schedules'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Maintain student placement database using Excel and SQL for tracking applications and interview schedules\n• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer\nGhaziabad, UP\n• Design promotional materials including posters, banners, and social media content for 20+ college events'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Team Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer\nGhaziabad, UP\n• Design promotional materials including posters, banners, and social media content for 20+ college events\n• Collaborate with team members using Figma and Canva to create cohesive visual branding campaigns'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Collaborate with team members using Figma and Canva to create cohesive visual branding campaigns\n• Apply data-driven design principles by analyzing engagement metrics to optimize visual content performance\nCertifications and Achievements'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Apply data-driven design principles by analyzing engagement metrics to optimize visual content performance\nCertifications and Achievements\nCertifications: AI and Data Science Program (IIT Kharagpur) | Machine Learning with Python (Coursera-IBM) | Java'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Certifications and Achievements\nCertifications: AI and Data Science Program (IIT Kharagpur) | Machine Learning with Python (Coursera-IBM) | Java\nDSA Bootcamp (Coding Ninjas) | SQL for Data Science (Coursera-UC Davis) | Python for DS and ML (Udemy)'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-12-09T06:06:33+00:00', 'source': '..\\data\\pdf\\bheeni resume.pdf', 'file_path': '..\\data\\pdf\\bheeni resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-12-09T06:06:33+00:00', 'trapped': '', 'modDate': 'D:20251209060633Z', 'creationDate': 'D:20251209060633Z', 'page': 0, 'source_file': 'bheeni resume.pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='DSA Bootcamp (Coding Ninjas) | SQL for Data Science (Coursera-UC Davis) | Python for DS and ML (Udemy)\nAchievements: GSSoC’25 Contributor - Selected for open-source ML projects | Top Performer - AI Camp by IIT KGP\n(Top 10% of 500+) | Best Project Award - Data Science Track by AKGEC faculty'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Suyash Singh\n\x83 8318176090\n# suyashsingh2711@gmail.com\nï linkedin.com/in/suyash-singh\n§ github.com/suyash503\nPROFESSIONAL SUMMARY\n3rd-year B.Tech Computer Science student at AKGEC with a high-impact focus on bridging the gap between Full-Stack'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='ï linkedin.com/in/suyash-singh\n§ github.com/suyash503\nPROFESSIONAL SUMMARY\n3rd-year B.Tech Computer Science student at AKGEC with a high-impact focus on bridging the gap between Full-Stack\nEngineering and Machine Learning. Expertly proficient in Python and JavaScript (React, Next.js), with a proven'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Engineering and Machine Learning. Expertly proficient in Python and JavaScript (React, Next.js), with a proven\ntrack record of architecting end-to-end predictive systems—from training XGBoost models to deploying high-concurrency'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='track record of architecting end-to-end predictive systems—from training XGBoost models to deploying high-concurrency\nAPIs with FastAPI. Recognized as a Training and Placement Cell Coordinator, managing data-driven recruitment'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='APIs with FastAPI. Recognized as a Training and Placement Cell Coordinator, managing data-driven recruitment\nworkflows while maintaining a portfolio of deployed applications featuring sub-100ms latency. Passionate about building'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='workflows while maintaining a portfolio of deployed applications featuring sub-100ms latency. Passionate about building\nscalable, data-intelligent products that prioritize performance and user-centric design.\nEDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='scalable, data-intelligent products that prioritize performance and user-centric design.\nEDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP\nBachelor of Technology in Computer Science and Engineering\nSept 2023 – Present\nMontfort Inter College\nLucknow, UP'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='EDUCATION\nAjay Kumar Garg Engineering College (AKGEC)\nGhaziabad, UP\nBachelor of Technology in Computer Science and Engineering\nSept 2023 – Present\nMontfort Inter College\nLucknow, UP\nSenior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Sept 2023 – Present\nMontfort Inter College\nLucknow, UP\nSenior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Senior Secondary Education (PCM)\nJuly 2022\nTECHNICAL SKILLS\nProgramming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Programming Languages: Python, C, C++, SQL, JavaScript\nWeb Development: React.js, Next.js, Tailwind CSS, Node.js, Express, MongoDB\nDeveloper Tools: Git, GitHub, VS Code, REST APIs, Postman\nML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Developer Tools: Git, GitHub, VS Code, REST APIs, Postman\nML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS\nEduHealth: AI-Driven Student Wellness Predictive System | Python, Scikit-learn, FastAPI, React.js'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='ML Architectures: Random Forest, XGBoost, Multilayer Perceptron (MLP), SHAP\nPROJECTS\nEduHealth: AI-Driven Student Wellness Predictive System | Python, Scikit-learn, FastAPI, React.js\n• Engineered a predictive pipeline using Random Forest and XGBoost to forecast student GPA with 94% accuracy,'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Engineered a predictive pipeline using Random Forest and XGBoost to forecast student GPA with 94% accuracy,\nanalyzing 20+ behavioral metrics.\n• Applied SHAP (Explainable AI) to interpret model decisions, identifying physical activity as a top-3 predictor of\nacademic success.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='analyzing 20+ behavioral metrics.\n• Applied SHAP (Explainable AI) to interpret model decisions, identifying physical activity as a top-3 predictor of\nacademic success.\n• Architected a high-concurrency interface with FastAPI to serve model inferences with sub-100ms response times.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='academic success.\n• Architected a high-concurrency interface with FastAPI to serve model inferences with sub-100ms response times.\n• Optimized model generalization using K-Fold Cross-Validation, ensuring a consistent R2 score of 0.95 across diverse\nstudent profiles.\nWORK EXPERIENCE'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Optimized model generalization using K-Fold Cross-Validation, ensuring a consistent R2 score of 0.95 across diverse\nstudent profiles.\nWORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='student profiles.\nWORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='WORK EXPERIENCE\nTraining and Placement Cell Coordinator\nAKGEC\n3rd Year Student Coordinator\nNov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.\n• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='Nov 2025 – Present\n• Coordinating recruitment drives and managing student data for placement activities.\n• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.\nCERTIFICATIONS\n• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Collaborating with corporate teams to facilitate smooth conduction of technical assessments.\nCERTIFICATIONS\n• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)\nVerify\n• The Web Developer Bootcamp 2025 – Udemy\nVerify\n• Google Digital Marketing Certificate – Google'),
#  Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-01-20T16:33:13+00:00', 'source': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'file_path': '..\\data\\pdf\\suyash_res (9) (1).pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-01-20T16:33:13+00:00', 'trapped': '', 'modDate': 'D:20260120163313Z', 'creationDate': 'D:20260120163313Z', 'page': 0, 'source_file': 'suyash_res (9) (1).pdf', 'file_type': 'pdf', 'page_label': 'Page 1'}, page_content='• Machine Learning Specialization – DeepLearning.AI & Stanford University (Coursera)\nVerify\n• The Web Developer Bootcamp 2025 – Udemy\nVerify\n• Google Digital Marketing Certificate – Google\nVerify\n• Marketing Internship – Universal Tribes\nCompleted June 2025')]

# %%
print(type(vectorstore))
# Out:
# <class '__main__.VectorStore'>

# %%
###  convertig text to embeddingss
texts=[doc.page_content for doc in chunks]

## Generate the Embeddings

embeddings=embedding_manager.generate_embeddings(texts)

##store int he vector dtaabase
# 'chunks' should be a list of Document objects
vectorstore.add_documents(chunks, embeddings)
# Out:
# generating embeddings for 59 texts...
# Batches: 100%|██████████| 2/2 [00:00<00:00,  2.15it/s]
# Generated embeddings with shape: (59, 384)
# Adding 59 documents to vector store...
# Successfully added 59 documents to vector store
# Total documents in collection: 295

# %% [markdown]
# ### Retriever Pipeline From VectorStore

# %%
class RAGRetriever:
    """Handles query-based retrieval from the vector store"""
    
    def __init__(self, vector_store: VectorStore, embedding_manager: EmbeddingManager):
        """
        Initialize the retriever
        
        Args:
            vectorstore: Vector store containing document embeddings
            embedding_manager: Manager for generating query embeddings
        """
        self.vector_store = vector_store
        self.embedding_manager = embedding_manager

    def retrieve(self, query: str, top_k: int = 5, score_threshold: float = 0.0) -> List[Dict[str, Any]]:
        """
        Retrieve relevant documents for a query
        
        Args:
            query: The search query
            top_k: Number of top results to return
            score_threshold: Minimum similarity score threshold
            
        Returns:
            List of dictionaries containing retrieved documents and metadata
        """
        print(f"Retrieving documents for query: '{query}'")
        print(f"Top K: {top_k}, Score threshold: {score_threshold}")
        
        # Generate query embedding
        query_embedding = self.embedding_manager.generate_embeddings([query])[0]
        
        # Search in vector store
        try:
            results = self.vector_store.collection.query(
                query_embeddings=[query_embedding.tolist()],
                n_results=top_k
            )
            
            # Process results
            retrieved_docs = []
            
            if results['documents'] and results['documents'][0]:
                documents = results['documents'][0]
                metadatas = results['metadatas'][0]
                distances = results['distances'][0]
                ids = results['ids'][0]
                
                for i, (doc_id, document, metadata, distance) in enumerate(zip(ids, documents, metadatas, distances)):
                    # Convert distance to similarity score , for checking the answer (ChromaDB uses cosine distance)
                    similarity_score = 1 - distance
                    
                    if similarity_score >= score_threshold:
                        retrieved_docs.append({
                            'id': doc_id,
                            'content': document,
                            'metadata': metadata,
                            'similarity_score': similarity_score,
                            'distance': distance,
                            'rank': i + 1
                        })
                
                print(f"Retrieved {len(retrieved_docs)} documents (after filtering)")
            else:
                print("No documents found")
            
            return retrieved_docs
            
        except Exception as e:
            print(f"Error during retrieval: {e}")
            return []

rag_retriever=RAGRetriever(vectorstore,embedding_manager)

# %%
rag_retriever.retrieve("ssist in organizing technical workshops mock interviews, and resume building sessions for career preparation Facilitate communication between recruiters and students improving placement proce")
# Out:
# Retrieving documents for query: 'ssist in organizing technical workshops mock interviews, and resume building sessions for career preparation Facilitate communication between recruiters and students improving placement proce'
# Top K: 5, Score threshold: 0.0
# generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.47it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents (after filtering)
# [{'id': 'doc_3f75ad75_30',
#   'content': '• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer',
#   'metadata': {'creationdate': '2025-12-09T06:06:33+00:00',
#    'doc_index': 30,
#    'trapped': '',
#    'page': 0,
#    'page_label': 'Page 1',
#    'author': '',
#    'title': '',
#    'format': 'PDF 1.5',
#    'content_length': 288,
#    'moddate': '2025-12-09T06:06:33+00:00',
#    'creationDate': 'D:20251209060633Z',
#    'modDate': 'D:20251209060633Z',
#    'source_file': 'bheeni resume.pdf',
#    'file_type': 'pdf',
#    'creator': 'LaTeX with hyperref',
#    'total_pages': 1,
#    'subject': '',
#    'source': '..\\data\\pdf\\bheeni resume.pdf',
#    'file_path': '..\\data\\pdf\\bheeni resume.pdf',
#    'producer': 'pdfTeX-1.40.27',
#    'keywords': ''},
#   'similarity_score': 0.34317195415496826,
#   'distance': 0.6568280458450317,
#   'rank': 1},
#  {'id': 'doc_904473fa_30',
#   'content': '• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer',
#   'metadata': {'page_label': 'Page 1',
#    'file_path': '..\\data\\pdf\\bheeni resume.pdf',
#    'producer': 'pdfTeX-1.40.27',
#    'title': '',
#    'format': 'PDF 1.5',
#    'moddate': '2025-12-09T06:06:33+00:00',
#    'creationDate': 'D:20251209060633Z',
#    'total_pages': 1,
#    'source_file': 'bheeni resume.pdf',
#    'trapped': '',
#    'modDate': 'D:20251209060633Z',
#    'author': '',
#    'subject': '',
#    'source': '..\\data\\pdf\\bheeni resume.pdf',
#    'page': 0,
#    'content_length': 288,
#    'keywords': '',
#    'file_type': 'pdf',
#    'doc_index': 30,
#    'creator': 'LaTeX with hyperref',
#    'creationdate': '2025-12-09T06:06:33+00:00'},
#   'similarity_score': 0.34317195415496826,
#   'distance': 0.6568280458450317,
#   'rank': 2},
#  {'id': 'doc_a65f289e_30',
#   'content': '• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer',
#   'metadata': {'moddate': '2025-12-09T06:06:33+00:00',
#    'format': 'PDF 1.5',
#    'subject': '',
#    'creator': 'LaTeX with hyperref',
#    'keywords': '',
#    'doc_index': 30,
#    'page': 0,
#    'creationDate': 'D:20251209060633Z',
#    'author': '',
#    'modDate': 'D:20251209060633Z',
#    'file_type': 'pdf',
#    'content_length': 288,
#    'page_label': 'Page 1',
#    'source_file': 'bheeni resume.pdf',
#    'creationdate': '2025-12-09T06:06:33+00:00',
#    'total_pages': 1,
#    'title': '',
#    'file_path': '..\\data\\pdf\\bheeni resume.pdf',
#    'producer': 'pdfTeX-1.40.27',
#    'source': '..\\data\\pdf\\bheeni resume.pdf',
#    'trapped': ''},
#   'similarity_score': 0.34317195415496826,
#   'distance': 0.6568280458450317,
#   'rank': 3},
#  {'id': 'doc_9bf249b1_30',
#   'content': '• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer',
#   'metadata': {'source': '..\\data\\pdf\\bheeni resume.pdf',
#    'moddate': '2025-12-09T06:06:33+00:00',
#    'content_length': 288,
#    'subject': '',
#    'source_file': 'bheeni resume.pdf',
#    'creationdate': '2025-12-09T06:06:33+00:00',
#    'author': '',
#    'file_path': '..\\data\\pdf\\bheeni resume.pdf',
#    'creationDate': 'D:20251209060633Z',
#    'keywords': '',
#    'title': '',
#    'trapped': '',
#    'total_pages': 1,
#    'page_label': 'Page 1',
#    'producer': 'pdfTeX-1.40.27',
#    'format': 'PDF 1.5',
#    'file_type': 'pdf',
#    'creator': 'LaTeX with hyperref',
#    'doc_index': 30,
#    'modDate': 'D:20251209060633Z',
#    'page': 0},
#   'similarity_score': 0.34317195415496826,
#   'distance': 0.6568280458450317,
#   'rank': 4},
#  {'id': 'doc_3d5d4f6d_30',
#   'content': '• Assist in organizing technical workshops, mock interviews, and resume building sessions for career preparation\n• Facilitate communication between recruiters and students improving placement process efficiency by 30%\nTeam Footprints, AKGEC\nMay 2025 – Present\nCreative Artist and Designer',
#   'metadata': {'total_pages': 1,
#    'creationDate': 'D:20251209060633Z',
#    'trapped': '',
#    'author': '',
#    'keywords': '',
#    'creationdate': '2025-12-09T06:06:33+00:00',
#    'doc_index': 30,
#    'producer': 'pdfTeX-1.40.27',
#    'modDate': 'D:20251209060633Z',
#    'title': '',
#    'subject': '',
#    'moddate': '2025-12-09T06:06:33+00:00',
#    'format': 'PDF 1.5',
#    'source': '..\\data\\pdf\\bheeni resume.pdf',
#    'content_length': 288,
#    'page_label': 'Page 1',
#    'file_type': 'pdf',
#    'page': 0,
#    'file_path': '..\\data\\pdf\\bheeni resume.pdf',
#    'creator': 'LaTeX with hyperref',
#    'source_file': 'bheeni resume.pdf'},
#   'similarity_score': 0.34317195415496826,
#   'distance': 0.6568280458450317,
#   'rank': 5}]

# %% [markdown]
# #RAG PIPELINE- VECTOR DB TO LLM OUTPUT GENERATION

# %%
import os
from dotenv import load_dotenv
load_dotenv()

print(os.getenv("GROQ_API_KEY"))
# Out:
# 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

# %%
# Updated modern imports
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import HumanMessage, SystemMessage

# %%
class GroqLLM:
    def __init__(self, model_name: str = "gemma2-9b-it", api_key: str =None):
        """
        Initialize Groq LLM
        
        Args:
            model_name: Groq model name (qwen2-72b-instruct, llama3-70b-8192, etc.)
            api_key: Groq API key (or set GROQ_API_KEY environment variable)
        """
        self.model_name = model_name
        self.api_key = api_key or os.environ.get("GROQ_API_KEY")
        
        if not self.api_key:
            raise ValueError("Groq API key is required. Set GROQ_API_KEY environment variable or pass api_key parameter.")
        
        self.llm = ChatGroq(
            groq_api_key=self.api_key,
            model_name=self.model_name,
            temperature=0.1,
            max_tokens=1024
        )
        
        print(f"Initialized Groq LLM with model: {self.model_name}")

    def generate_response(self, query: str, context: str, max_length: int = 500) -> str:
        """
        Generate response using retrieved context
        
        Args:
            query: User question
            context: Retrieved document context
            max_length: Maximum response length
            
        Returns:
            Generated response string
        """
        
        # Create prompt template
        prompt_template = PromptTemplate(
            input_variables=["context", "question"],
            template="""You are a helpful AI assistant. Use the following context to answer the question accurately and concisely.

Context:
{context}

Question: {question}

Answer: Provide a clear and informative answer based on the context above. If the context doesn't contain enough information to answer the question, say so."""
        )
        
        # Format the prompt
        formatted_prompt = prompt_template.format(context=context, question=query)
        
        try:
            # Generate response
            messages = [HumanMessage(content=formatted_prompt)]
            response = self.llm.invoke(messages)
            return response.content
            
        except Exception as e:
            return f"Error generating response: {str(e)}"
        
    def generate_response_simple(self, query: str, context: str) -> str:
        """
        Simple response generation without complex prompting
        
        Args:
            query: User question
            context: Retrieved context
            
        Returns:
            Generated response
        """
        simple_prompt = f"""Based on this context: {context}

Question: {query}

Answer:"""
        
        try:
            messages = [HumanMessage(content=simple_prompt)]
            response = self.llm.invoke(messages)
            return response.content
        except Exception as e:
            return f"Error: {str(e)}"

# %%
# Initialize Groq LLM (you'll need to set GROQ_API_KEY environment variable)
try:
    groq_llm = GroqLLM(api_key=os.getenv("GROQ_API_KEY"))
    print("Groq LLM initialized successfully!")
except ValueError as e:
    print(f"Warning: {e}")
    print("Please set your GROQ_API_KEY environment variable to use the LLM.")
    groq_llm = None
# Out:
# Initialized Groq LLM with model: gemma2-9b-it
# Groq LLM initialized successfully!

# %%
### get the context from the retriever and pass it to the LLM

rag_retriever.retrieve("Unified Multi-task Learning Framework")
# Out:
# Retrieving documents for query: 'Unified Multi-task Learning Framework'
# Top K: 5, Score threshold: 0.0
# generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.56it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 0 documents (after filtering)
# []

# %% [markdown]
# ### Integration Vectordb Context pipeline With LLM output

# %%
### Simple RAG pipeline with Groq LLM
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv
load_dotenv()

### Initialize the Groq LLM (set your GROQ_API_KEY in environment)
groq_api_key = os.getenv("GROQ_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key,model_name="gemma2-9b-it",temperature=0.1,max_tokens=1024)

## 2. Simple RAG function: retrieve context + generate response
def rag_simple(query,retriever,llm,top_k=3):
    ## retriever the context
    results=retriever.retrieve(query,top_k=top_k)
    context="\n\n".join([doc['content'] for doc in results]) if results else ""
    if not context:
        return "No relevant context found to answer the question."
    
    ## generate the answwer using GROQ LLM
    prompt=f"""Use the following context to answer the question concisely.
        Context:
        {context}

        Question: {query}

        Answer:"""
    
    response=llm.invoke([prompt.format(context=context,query=query)])
    return response.content

# %%
answer=rag_simple("Project",rag_retriever,llm)
print(answer)
# Out:
# Retrieving documents for query: 'Project'
# Top K: 3, Score threshold: 0.0
# generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.18it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 0 documents (after filtering)
# No relevant context found to answer the question.

# %% [markdown]
# ### Enhanced RAG Pipeline Features

# %%
# --- Enhanced RAG Pipeline Features ---
def rag_advanced(query, retriever, llm, top_k=5, min_score=0.2, return_context=False):
    """
    RAG pipeline with extra features:
    - Returns answer, sources, confidence score, and optionally full context.
    """
    results = retriever.retrieve(query, top_k=top_k, score_threshold=min_score)
    if not results:
        return {'answer': 'No relevant context found.', 'sources': [], 'confidence': 0.0, 'context': ''}
    
    # Prepare context and sources
    context = "\n\n".join([doc['content'] for doc in results])
    sources = [{
        'source': doc['metadata'].get('source_file', doc['metadata'].get('source', 'unknown')),
        'page': doc['metadata'].get('page', 'unknown'),
        'score': doc['similarity_score'],
        'preview': doc['content'][:300] + '...'
    } for doc in results]
    confidence = max([doc['similarity_score'] for doc in results])
    
    # Generate answer
    prompt = f"""Use the following context to answer the question concisely.\nContext:\n{context}\n\nQuestion: {query}\n\nAnswer:"""
    response = llm.invoke([prompt.format(context=context, query=query)])
    
    output = {
        'answer': response.content,
        'sources': sources,
        'confidence': confidence
    }
    if return_context:
        output['context'] = context
    return output

# Example usage:
result = rag_advanced("Hard Negative Mining Technqiues", rag_retriever, llm, top_k=3, min_score=0.1, return_context=True)
print("Answer:", result['answer'])
print("Sources:", result['sources'])
print("Confidence:", result['confidence'])
print("Context Preview:", result['context'][:300])
# Out:
# Retrieving documents for query: 'Hard Negative Mining Technqiues'
# Top K: 3, Score threshold: 0.1
# generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00,  8.85it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 0 documents (after filtering)
# Answer: No relevant context found.
# Sources: []
# Confidence: 0.0
# Context Preview:
